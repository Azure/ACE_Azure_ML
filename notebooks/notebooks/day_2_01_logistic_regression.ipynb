# %% [markdown]
# ##![LearnAI Header](https://coursematerial.blob.core.windows.net/assets/LearnAI_header.png)

# %% [markdown]
# -sandbox
#
# # Getting started with Machine Learning for Predictive Maintenance
#
# In this lab, we will create our first Machine Learning solution for predictive maintenance. We will rely on a simple but powerful algorithm: [Logistic Regression](https://en.wikipedia.org/wiki/Logistic_regression).

# %% [markdown]
# ## Reading the data

# %% [markdown]
# We begin by reading the data that we finished pre-processing in a prior Notebook.
#
# > *Note:* If you you do get an error messages about a non-existent file, run the *feature_engineering* notebook of day 1 once more. Unfortunately, this will take a couple of minutes.

# %%
df = spark.read.parquet("dbfs:/FileStore/tables/preprocessed").cache()
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>machineID</th><th>datetime</th><th>age</th><th>diff_error_0</th><th>diff_error_1</th><th>diff_error_2</th><th>diff_error_3</th><th>diff_error_4</th><th>diff_fail_0</th><th>diff_fail_1</th><th>diff_fail_2</th><th>diff_fail_3</th><th>diff_maint_0</th><th>diff_maint_1</th><th>diff_maint_2</th><th>diff_maint_3</th><th>pressure_ma_3</th><th>pressure_sd_3</th><th>rotate_ma_3</th><th>rotate_sd_3</th><th>vibration_ma_3</th><th>vibration_sd_3</th><th>volt_ma_3</th><th>volt_sd_3</th><th>y_0</th><th>y_1</th><th>y_2</th><th>y_3</th></tr></thead><tbody><tr><td>16</td><td>2015-06-10T23:00:00.000+0000</td><td>3</td><td>489.0</td><td>318.0</td><td>257.0</td><td>617.0</td><td>2142.0</td><td>1673.0</td><td>233.0</td><td>593.0</td><td>3957.0</td><td>953.0</td><td>233.0</td><td>593.0</td><td>1313.0</td><td>103.36172205524505</td><td>7.328405874766052</td><td>470.40251318654725</td><td>92.20329334384515</td><td>36.4696066569045</td><td>3.3063509142485454</td><td>162.77538146117274</td><td>17.15059004541141</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>16</td><td>2015-06-11T00:00:00.000+0000</td><td>3</td><td>490.0</td><td>319.0</td><td>258.0</td><td>618.0</td><td>2143.0</td><td>1674.0</td><td>234.0</td><td>594.0</td><td>3958.0</td><td>954.0</td><td>234.0</td><td>594.0</td><td>1314.0</td><td>99.363131214606</td><td>10.871060485258129</td><td>446.91811499211394</td><td>82.57552287693811</td><td>38.15925421485703</td><td>5.68406531953323</td><td>170.811166158514</td><td>1.9468855435949943</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>16</td><td>2015-06-11T01:00:00.000+0000</td><td>3</td><td>491.0</td><td>320.0</td><td>259.0</td><td>619.0</td><td>2144.0</td><td>1675.0</td><td>235.0</td><td>595.0</td><td>3959.0</td><td>955.0</td><td>235.0</td><td>595.0</td><td>1315.0</td><td>101.39131534989146</td><td>10.023193445589618</td><td>440.04974209269324</td><td>78.79381696420629</td><td>41.111666609672355</td><td>4.009084955041661</td><td>172.64899000407274</td><td>5.118941409799331</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>16</td><td>2015-06-11T02:00:00.000+0000</td><td>3</td><td>492.0</td><td>321.0</td><td>260.0</td><td>620.0</td><td>2145.0</td><td>1676.0</td><td>236.0</td><td>596.0</td><td>3960.0</td><td>956.0</td><td>236.0</td><td>596.0</td><td>1316.0</td><td>98.36866553478745</td><td>8.587414855405909</td><td>472.6304420269753</td><td>36.17558170016903</td><td>40.805403622712525</td><td>4.297997479151865</td><td>168.56396337307723</td><td>11.543020480874953</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>16</td><td>2015-06-11T03:00:00.000+0000</td><td>3</td><td>493.0</td><td>322.0</td><td>261.0</td><td>621.0</td><td>2146.0</td><td>1677.0</td><td>237.0</td><td>597.0</td><td>3961.0</td><td>957.0</td><td>237.0</td><td>597.0</td><td>1317.0</td><td>94.53421765518715</td><td>5.968726222941755</td><td>460.0051519863225</td><td>14.962694219838605</td><td>40.318859899470176</td><td>4.948653154935858</td><td>165.95955799828124</td><td>11.578897552357208</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>16</td><td>2015-06-11T04:00:00.000+0000</td><td>3</td><td>494.0</td><td>323.0</td><td>262.0</td><td>622.0</td><td>2147.0</td><td>1678.0</td><td>238.0</td><td>598.0</td><td>3962.0</td><td>958.0</td><td>238.0</td><td>598.0</td><td>1318.0</td><td>95.50008347465094</td><td>4.557688829884692</td><td>463.05209361891275</td><td>9.315773330681766</td><td>40.23520369738577</td><td>4.834785987328766</td><td>169.3007077087945</td><td>14.443743556629142</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>16</td><td>2015-06-11T05:00:00.000+0000</td><td>3</td><td>495.0</td><td>324.0</td><td>263.0</td><td>623.0</td><td>2148.0</td><td>1679.0</td><td>239.0</td><td>599.0</td><td>3963.0</td><td>959.0</td><td>239.0</td><td>599.0</td><td>1319.0</td><td>93.33858647635662</td><td>2.6168933071748706</td><td>469.4177 ...

# %%
from pyspark.ml.feature import StandardScaler, VectorAssembler
from pyspark.ml import Pipeline

keys = ['machineID', 'datetime']
X_keep = ['diff_maint_1', 'diff_error_1', 'volt_sd_3', 'diff_fail_3', 'pressure_ma_3', 'pressure_sd_3', 'diff_fail_1', 'diff_fail_0', 'age', 'vibration_ma_3', 'rotate_ma_3', 'diff_error_2', 'diff_fail_2', 'diff_error_3', 'diff_maint_2', 'volt_ma_3', 'diff_maint_0', 'vibration_sd_3', 'diff_maint_3', 'rotate_sd_3', 'diff_error_0', 'diff_error_4']
Y_keep = ['y_0', 'y_1', 'y_2', 'y_3']

vassembler = VectorAssembler(inputCols = X_keep, outputCol = "features")
stndscaler = StandardScaler(inputCol = "features", outputCol = "norm_features")

pipeline = Pipeline(stages = [vassembler, stndscaler])
df_norm = pipeline.fit(df).transform(df).select(keys + ["norm_features"] + Y_keep)
display(df_norm)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>machineID</th><th>datetime</th><th>norm_features</th><th>y_0</th><th>y_1</th><th>y_2</th><th>y_3</th></tr></thead><tbody><tr><td>16</td><td>2015-06-10T23:00:00.000+0000</td><td>List(1, 22, List(), List(0.20952993119406246, 0.3348105818258993, 2.9340970661577592, 1.5719932532053056, 15.161634257041639, 1.8693599215101442, 0.12001661058038639, 0.7754073254874088, 0.5147900362625834, 11.540620742484096, 15.802437535752096, 0.2566995351267684, 0.22541394137012827, 0.5941540693074987, 0.555498311305963, 19.261202705974416, 0.9069586781562903, 1.6933771813998613, 1.1116810754241957, 4.729865538607657, 0.6097039463397917, 1.223219863982335))</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>16</td><td>2015-06-11T00:00:00.000+0000</td><td>List(1, 22, List(), List(0.21042920128502413, 0.3358634452907606, 0.3330702411101798, 1.5723905221598684, 14.575100183654946, 2.7730348349603267, 0.12053170332965843, 0.7758708086466959, 0.5147900362625834, 12.07530108160157, 15.013515867331735, 0.2576983660027481, 0.22579406606046573, 0.5951170418671543, 0.5564350706842193, 20.212076705271276, 0.9079103661711447, 2.9111448721925743, 1.1125277479873519, 4.235977976747721, 0.6109507846758649, 1.223790928344605))</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>16</td><td>2015-06-11T01:00:00.000+0000</td><td>List(1, 22, List(), List(0.21132847137598576, 0.33691630875562195, 0.8757407723324422, 1.5727877911144312, 14.872604767108934, 2.5567574221353495, 0.12104679607893047, 0.776334291805983, 0.5147900362625834, 13.009576903233503, 14.782783610014254, 0.2586971968787277, 0.22617419075080322, 0.5960800144268099, 0.5573718300624755, 20.429546308533265, 0.9088620541859992, 2.053288703236145, 1.1133744205505083, 4.041983165661366, 0.6121976230119381, 1.224361992706875))</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>16</td><td>2015-06-11T02:00:00.000+0000</td><td>List(1, 22, List(), List(0.2122277414669474, 0.3379691722204832, 1.974762526412058, 1.573185060068994, 14.429226792434449, 2.1905131121833645, 0.12156188882820251, 0.7767977749652701, 0.5147900362625834, 12.912661545379086, 15.87728132452455, 0.25969602775470735, 0.2265543154411407, 0.5970429869864655, 0.5583085894407318, 19.946165312632008, 0.9098137422008536, 2.201257835502328, 1.1142210931136645, 1.85574322800626, 0.6134444613480113, 1.224933057069145))</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>16</td><td>2015-06-11T03:00:00.000+0000</td><td>List(1, 22, List(), List(0.21312701155790903, 0.33902203568534456, 1.980900321665731, 1.573582329023557, 13.86677006113971, 1.522527241845776, 0.12207698157747456, 0.7772612581245574, 0.5147900362625834, 12.758697269388929, 15.453154429694273, 0.260694858630687, 0.2269344401314782, 0.5980059595461211, 0.559245348818988, 19.637986155549584, 0.9107654302157081, 2.5344969570888316, 1.1150677656768206, 0.7675596954136652, 0.6146912996840845, 1.225504121431415))</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>16</td><td>2015-06-11T04:00:00.000+0000</td><td>List(1, 22, List(), List(0.2140262816488707, 0.3400748991502059, 2.47101385326268, 1.57397959797812, 14.008448276294258, 1.1625940182485999, 0.12259207432674661, 0.7777247412838445, 0.5147900362625834, 12.732224691549103, 15.555511673702012, 0.26169368950666666, 0.22731456482181567, 0.5989689321057767, 0.5601821081972443, 20.033344232843074, 0.9117171182305626, 2.4761788691612816, 1.115914438239977, 0.47788266171745436, 0.6159381380201577, 1.226075185793685))</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>16</td><td>2015-06-11T05:00:00.000+0000</td><td>List(1, 22, List(), List(0.21492555173983233, 0.3411277626150672, 2.1566803166002755, 1.5743768669326828, 13.691388669660423, 0.6675279113763612, 0.12310716707601865, 0.7781882244431316, 0.5147900362625834, 12.36771234148782, 15.7693547156615, 0.2626925203826463, 0.22769468951215316, 0.59 ...

# %% [markdown]
# Let's begin by dividing the data into training and test sets. With time-series data, we usually divide the data based on a time cut-off and to avoid **leakage** we also put a gap (2 weeks in this case) between the training and test data. Another option we have is to sample every n-th row of the data. The data is collected hourly, and if we do not wish to use such a high frequency for modeling, we can sample every n-th row of the data.

# %%
# from pyspark.sql.types import DateType
from pandas import datetime
from pyspark.sql.functions import col, hour

# we sample every nth row of the data using the `hour` function
df_train = df_norm.filter((col('datetime') < datetime(2015, 10, 1))) # & (hour(col('datetime')) % 3 == 0))
df_test = df_norm.filter(col('datetime') > datetime(2015, 10, 15))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Let's look at some summary statistics for the labels in the data.

# %%
display(df_train.describe())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>machineID</th><th>y_0</th><th>y_1</th><th>y_2</th><th>y_3</th></tr></thead><tbody><tr><td>count</td><td>654600</td><td>654600</td><td>654600</td><td>654600</td><td>654600</td></tr><tr><td>mean</td><td>50.5</td><td>0.014637946837763519</td><td>0.01884967919340055</td><td>0.010820348304307975</td><td>0.015073327222731438</td></tr><tr><td>stddev</td><td>28.866092096380104</td><td>0.1200987068394558</td><td>0.13599410663951864</td><td>0.10345668039212999</td><td>0.12184475659168902</td></tr><tr><td>min</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>max</td><td>100</td><td>1</td><td>1</td><td>1</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# We now build a classifier for `y_0` (failure in the first component) (and drop the other labels).

# %%
df_train = df_train.drop("y_1","y_2","y_3","datetime", "machineID")
df_train = df_train.withColumnRenamed("y_0", "error")
df_train.cache()

df_test = df_test.drop("y_1","y_2","y_3","datetime", "machineID")
df_test = df_test.withColumnRenamed("y_0", "error")
df_test.cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">8</span><span class="ansired">]: </span>DataFrame[norm_features: vector, error: int]
# </div>

# %% [markdown]
# Let's make sure we don't have any null values in our DataFrame.

# %%
recordCount = df_train.count()
noNullsRecordCount = df_train.na.drop().count()

print("We have {} records that contain null values.".format(recordCount - noNullsRecordCount))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">We have 0 records that contain null values.
# </div>

# %%
display(df_train.groupBy("error").count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>error</th><th>count</th></tr></thead><tbody><tr><td>1</td><td>9582</td></tr><tr><td>0</td><td>645018</td></tr></tbody></table></div>

# %% [markdown]
# ## Train a Logistic Regression Model
#
# Before we can apply the logistic regression model, we will need to do some data preparation, such as one hot encoding our categorical variables using `StringIndexer` and `OneHotEncoderEstimator`.
#
# Let's start by taking a look at all of our columns, and determine which ones are categorical.

# %%
df_train.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- norm_features: vector (nullable = true)
# -- error: integer (nullable = true)
#
# </div>

# %% [markdown]
# ## Setting up the model
#
# We set the `label` column of the LogisticRegression model to `error`, and the `features` column to `norm_features`.

# %%
from pyspark.ml.classification import LogisticRegression

lr = (LogisticRegression()
     .setLabelCol("error")
     .setFeaturesCol("norm_features"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Hands-on lab
# Create a pipeline that contains a single stage for the model we created above. Then fit the pipeline to the training data and then use the fitted model to `transform` the test data.

# %%
# maximize this cell (click the + button on the right) to see the solution:
  
from pyspark.ml import Pipeline

pipeline = Pipeline(stages = [lr])
assert len(pipeline.getStages()) == 1 # make sure it's one stage only
print(pipeline.getStages())

lr_model = pipeline.fit(df_train)

df_pred = lr_model.transform(df_test) # apply the model to our held-out test set
display(df_pred)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>norm_features</th><th>error</th><th>rawPrediction</th><th>probability</th><th>prediction</th></tr></thead><tbody><tr><td>List(1, 22, List(), List(2.2832467609516076, 2.51529081755369, 1.519700411830627, 2.774129109712572, 14.65828837599718, 1.4499966578532955, 1.6786872698775932, 1.3436376787734596, 0.5147900362625834, 12.71478234851845, 14.398613631067803, 0.25270421162284984, 0.007222369116412204, 0.04140782006519035, 0.017798428186868966, 21.80336393439427, 0.7032974429774381, 1.602436692749368, 1.844899515117534, 3.1141913325801536, 0.6296533597169628, 2.951260624211348))</td><td>0</td><td>List(1, 2, List(), List(3.9330722076386344, -3.9330722076386344))</td><td>List(1, 2, List(), List(0.9807927282668616, 0.019207271733138492))</td><td>0.0</td></tr><tr><td>List(1, 22, List(), List(2.2841460310425696, 2.5163436810185513, 1.2612647514705175, 2.7745263786671353, 13.913312489502026, 2.6689505781880656, 1.6792023626268653, 1.3441011619327468, 0.5147900362625834, 11.97281894929179, 15.280736027161465, 0.25370304249882947, 0.007602493806749688, 0.04237079262484594, 0.018735187565125228, 21.929706767556553, 0.7042491309922926, 2.917787940331837, 1.8457461876806904, 1.5608621270179244, 0.630900198053036, 2.951831688573618))</td><td>0</td><td>List(1, 2, List(), List(3.695768493561573, -3.695768493561573))</td><td>List(1, 2, List(), List(0.9757731472741494, 0.024226852725850578))</td><td>0.0</td></tr><tr><td>List(1, 22, List(), List(2.285045301133531, 2.5173965444834128, 1.555753196551649, 2.774923647621698, 14.28985610522001, 3.426542448341677, 1.6797174553761374, 1.3445646450920339, 0.5147900362625834, 11.369869738948456, 15.052497472245376, 0.25470187337480915, 0.007982618497087172, 0.04333376518450153, 0.01967194694338149, 21.61932052145031, 0.705200819007147, 1.8959090643538812, 1.8465928602438466, 1.8293690246135266, 0.6321470363891092, 2.952402752935888))</td><td>0</td><td>List(1, 2, List(), List(3.9905525322847843, -3.9905525322847843))</td><td>List(1, 2, List(), List(0.9818461600830883, 0.018153839916911697))</td><td>0.0</td></tr><tr><td>List(1, 22, List(), List(2.285944571224493, 2.5184494079482738, 3.117309020907023, 2.775320916576261, 13.661653347346657, 3.322156181515168, 1.6802325481254095, 1.345028128251321, 0.5147900362625834, 11.54527264471829, 14.777740364249428, 0.2557007042507888, 0.008362743187424656, 0.04429673774415712, 0.020608706321637752, 20.702627995836455, 0.7061525070220015, 2.295240674600147, 1.847439532807003, 2.3446082047151386, 0.6333938747251824, 2.952973817298158))</td><td>0</td><td>List(1, 2, List(), List(4.881757811923947, -4.881757811923947))</td><td>List(1, 2, List(), List(0.9924734075696523, 0.007526592430347835))</td><td>0.0</td></tr><tr><td>List(1, 22, List(), List(2.2868438413154544, 2.519502271413135, 2.0559155633955006, 2.7757181855308235, 13.347413778390939, 3.5722335442979083, 1.6807476408746813, 1.3454916114106081, 0.5147900362625834, 12.020891484985283, 14.606011399943256, 0.2566995351267684, 0.008742867877762142, 0.045259710303812706, 0.02154546569989401, 19.84231744673155, 0.7071041950368558, 2.8322702762557097, 1.8482862053701592, 1.9409373106097214, 0.6346407130612556, 2.953544881660428))</td><td>0</td><td>List(1, 2, List(), List(5.931536390031717, -5.931536390031717))</td><td>List(1, 2, List(), List(0.9973526265302755, 0.002647373469724598))</td><td>0.0</td></tr><tr><td>List(1, 22, List(), List(2.287743111406416, 2.5205551348779967, 2.268692880665532, 2.7761154544853865, 14.438656460947767, 3.8674317308246002, 1.6812627336239534, 1.3459550945698953, 0.5147900362625834, 12.207976982600718, 15.102024163892331, 0.2576983660027481, 0.009122992568099626, 0.0462226828634683, 0.022482225078150272, 19.957793549907436, 0.7080558830517103, 2.317763587651063, 1.8491328779333156, 2.853218066875978, 0.6358875513973288, 2.954115946022698))</td><td>0</td><td>List(1, 2, List(), L ...

# %% [markdown]
# ### End of lab

# %%
df_pred.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- norm_features: vector (nullable = true)
# -- error: integer (nullable = true)
# -- rawPrediction: vector (nullable = true)
# -- probability: vector (nullable = true)
# -- prediction: double (nullable = false)
#
# </div>

# %% [markdown]
# ## Evaluate the Model

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator

evaluator = BinaryClassificationEvaluator()
print(evaluator.explainParams())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">labelCol: label column name. (default: label)
# metricName: metric name in evaluation (areaUnderROC|areaUnderPR) (default: areaUnderROC)
# rawPredictionCol: raw prediction (a.k.a. confidence) column name. (default: rawPrediction)
# </div>

# %%
evaluator.setLabelCol("error")
evaluator.setRawPredictionCol('rawPrediction')

metricName = evaluator.getMetricName()
metricVal = evaluator.evaluate(df_pred)

print("{}: {}".format(metricName, metricVal))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">areaUnderROC: 0.8079406471710848
# </div>

# %% [markdown]
# We could wrap this into a function to make it easier to get the output of multiple metrics.

# %%
evaluator = BinaryClassificationEvaluator()
evaluator.setLabelCol("error")
evaluator.setRawPredictionCol("rawPrediction")

auroc = evaluator.setMetricName("areaUnderROC").evaluate(df_pred)

print("AUROC: {}".format(auroc))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">AUROC: 0.807940647171046
# </div>

# %% [markdown]
# ##Conclusion
# Hmmmm... our results are not great yet. We'll look into how to improve our results later.

# %%
# You can ignore this code, we use it for testing our notebooks.
assert auroc > .8
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
#
# Licensed under the MIT License.
