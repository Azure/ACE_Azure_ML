# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
#
# Licensed under the MIT License.

# %% [markdown]
# -sandbox
# #Logistic Regression Lab

# %% [markdown]
# ## Getting Started
#
# Run the following cell to configure our "classroom."

# %%
# %run "../includes/setup_env"

# %% [markdown]
# ## Reading the data

# %% [markdown]
# We begin by reading the data that we finished pre-processing in a prior Notebook.

# %%
df = spark.read.parquet("dbfs:/FileStore/tables/processed").cache()
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>machineID</th><th>datetime</th><th>age</th><th>diff_error_0</th><th>diff_error_1</th><th>diff_error_2</th><th>diff_error_3</th><th>diff_error_4</th><th>diff_fail_0</th><th>diff_fail_1</th><th>diff_fail_2</th><th>diff_fail_3</th><th>diff_maint_0</th><th>diff_maint_1</th><th>diff_maint_2</th><th>diff_maint_3</th><th>pressure_ma_3</th><th>pressure_sd_3</th><th>rotate_ma_3</th><th>rotate_sd_3</th><th>vibration_ma_3</th><th>vibration_sd_3</th><th>volt_ma_3</th><th>volt_sd_3</th><th>y_0</th><th>y_1</th><th>y_2</th><th>y_3</th></tr></thead><tbody><tr><td>68</td><td>2015-06-02T02:00:00.000+0000</td><td>10</td><td>886.0</td><td>202.0</td><td>788.0</td><td>437.0</td><td>560.0</td><td>3744.0</td><td>1460.0</td><td>3744.0</td><td>3744.0</td><td>3620.0</td><td>1460.0</td><td>740.0</td><td>20.0</td><td>103.81582891024671</td><td>9.253355581538184</td><td>430.58641300972477</td><td>31.493749995315138</td><td>40.16587598649302</td><td>1.6465389692984078</td><td>158.83585185687275</td><td>9.677727435020747</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>68</td><td>2015-06-02T03:00:00.000+0000</td><td>10</td><td>887.0</td><td>203.0</td><td>789.0</td><td>438.0</td><td>561.0</td><td>3745.0</td><td>1461.0</td><td>3745.0</td><td>3745.0</td><td>3621.0</td><td>1461.0</td><td>741.0</td><td>21.0</td><td>102.7507371894521</td><td>9.460262539149179</td><td>449.09793827832</td><td>54.36847047577793</td><td>39.292276658410074</td><td>3.1737452872067906</td><td>155.62002882053525</td><td>5.934378021697804</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>68</td><td>2015-06-02T04:00:00.000+0000</td><td>10</td><td>888.0</td><td>204.0</td><td>790.0</td><td>439.0</td><td>562.0</td><td>3746.0</td><td>1462.0</td><td>3746.0</td><td>3746.0</td><td>3622.0</td><td>1462.0</td><td>742.0</td><td>22.0</td><td>98.40865905366375</td><td>9.921132987103828</td><td>454.0176178799003</td><td>46.821480283802394</td><td>39.63602781157347</td><td>3.2519960046284395</td><td>163.26790949871298</td><td>9.867349880395764</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>68</td><td>2015-06-02T05:00:00.000+0000</td><td>10</td><td>889.0</td><td>205.0</td><td>791.0</td><td>440.0</td><td>563.0</td><td>3747.0</td><td>1463.0</td><td>3747.0</td><td>3747.0</td><td>3623.0</td><td>1463.0</td><td>743.0</td><td>23.0</td><td>100.127746015699</td><td>8.682544288547872</td><td>412.387178314523</td><td>98.77834311146349</td><td>39.01357833550013</td><td>2.8780722984542235</td><td>169.02554035058023</td><td>11.294482815047914</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>68</td><td>2015-06-02T06:00:00.000+0000</td><td>10</td><td>890.0</td><td>206.0</td><td>792.0</td><td>441.0</td><td>564.0</td><td>3748.0</td><td>1464.0</td><td>3748.0</td><td>3748.0</td><td>3624.0</td><td>1464.0</td><td>744.0</td><td>24.0</td><td>96.3241649042921</td><td>3.6983324929521357</td><td>395.977662295249</td><td>96.33139535678909</td><td>37.762429946503076</td><td>2.771101520027839</td><td>169.59476838986802</td><td>10.807074027044104</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>68</td><td>2015-06-02T07:00:00.000+0000</td><td>10</td><td>891.0</td><td>207.0</td><td>793.0</td><td>442.0</td><td>565.0</td><td>3749.0</td><td>1465.0</td><td>3749.0</td><td>3749.0</td><td>3625.0</td><td>1465.0</td><td>745.0</td><td>25.0</td><td>90.43571483782621</td><td>9.897125296488285</td><td>391.5564311429545</td><td>89.07959128648875</td><td>39.71850602993253</td><td>2.7650199464818943</td><td>167.53496086774126</td><td>14.127546346089515</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>68</td><td>2015-06-02T08:00:00.000+0000</td><td>10</td><td>892.0</td><td>208.0</td><td>794.0</td><td>443.0</td><td>566.0</td><td>3750.0</td><td>1466.0</td><td>3750.0</td><td>3750.0</td><td>3626.0</td><td>1466.0</td><td>746.0</td><td>26.0</td><td>94.40597784494906</td><td>12.972792141283701</td ...

# %% [markdown]
# Let's begin by dividing the data into training and test sets. With time-series data, we usually divide the data based on a time cut-off and to avoid **leakage** we also put a gap (2 weeks in this case) between the training and test data. Another option we have is to sample every n-th row of the data. The data is collected hourly, and if we do not wish to use such a high frequency for modeling, we can sample every n-th row of the data.

# %%
# from pyspark.sql.types import DateType
from pandas import datetime
from pyspark.sql.functions import col, hour

# we sample every nth row of the data using the `hour` function
df_train = df.filter((col('datetime') < datetime(2015, 10, 1))) # & (hour(col('datetime')) % 3 == 0))
df_test = df.filter(col('datetime') > datetime(2015, 10, 15))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Let's look at some summary statistics for the labels in the data.

# %%
display(df_train.describe())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>machineID</th><th>age</th><th>diff_error_0</th><th>diff_error_1</th><th>diff_error_2</th><th>diff_error_3</th><th>diff_error_4</th><th>diff_fail_0</th><th>diff_fail_1</th><th>diff_fail_2</th><th>diff_fail_3</th><th>diff_maint_0</th><th>diff_maint_1</th><th>diff_maint_2</th><th>diff_maint_3</th><th>pressure_ma_3</th><th>pressure_sd_3</th><th>rotate_ma_3</th><th>rotate_sd_3</th><th>vibration_ma_3</th><th>vibration_sd_3</th><th>volt_ma_3</th><th>volt_sd_3</th><th>y_0</th><th>y_1</th><th>y_2</th><th>y_3</th></tr></thead><tbody><tr><td>count</td><td>654600</td><td>654600</td><td>654600</td><td>654600</td><td>654600</td><td>654600</td><td>654600</td><td>654600</td><td>654600</td><td>654600</td><td>654600</td><td>654600</td><td>654600</td><td>654600</td><td>654600</td><td>654600</td><td>654600</td><td>654600</td><td>654600</td><td>654600</td><td>654600</td><td>654600</td><td>654600</td><td>654600</td><td>654600</td><td>654600</
cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">18</span><span class="ansired">]: </span>DataFrame[age: int, diff_error_0: double, diff_error_1: double, diff_error_2: double, diff_error_3: double, diff_error_4: double, diff_fail_0: double, diff_fail_1: double, diff_fail_2: double, diff_fail_3: double, diff_maint_0: double, diff_maint_1: double, diff_maint_2: double, diff_maint_3: double, pressure_ma_3: double, pressure_sd_3: double, rotate_ma_3: double, rotate_sd_3: double, vibration_ma_3: double, vibration_sd_3: double, volt_ma_3: double, volt_sd_3: double, error: int]
# </div>

# %% [markdown]
# Let's make sure we don't have any null values in our DataFrame.

# %%
recordCount = df_train.count()
noNullsRecordCount = df_train.na.drop().count()

print("We have {} records that contain null values.".format(recordCount - noNullsRecordCount))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">We have 0 records that contain null values.
# </div>

# %%
display(df_train.groupBy("error").count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>error</th><th>count</th></tr></thead><tbody><tr><td>1</td><td>9582</td></tr><tr><td>0</td><td>645018</td></tr></tbody></table></div>

# %% [markdown]
# ## Train a Logistic Regression Model
#
# Before we can apply the logistic regression model, we will need to do some data preparation, such as one hot encoding our categorical variables using `StringIndexer` and `OneHotEncoderEstimator`.
#
# Let's start by taking a look at all of our columns, and determine which ones are categorical.

# %%
df_train.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- age: integer (nullable = true)
# -- diff_error_0: double (nullable = true)
# -- diff_error_1: double (nullable = true)
# -- diff_error_2: double (nullable = true)
# -- diff_error_3: double (nullable = true)
# -- diff_error_4: double (nullable = true)
# -- diff_fail_0: double (nullable = true)
# -- diff_fail_1: double (nullable = true)
# -- diff_fail_2: double (nullable = true)
# -- diff_fail_3: double (nullable = true)
# -- diff_maint_0: double (nullable = true)
# -- diff_maint_1: double (nullable = true)
# -- diff_maint_2: double (nullable = true)
# -- diff_maint_3: double (nullable = true)
# -- pressure_ma_3: double (nullable = true)
# -- pressure_sd_3: double (nullable = true)
# -- rotate_ma_3: double (nullable = true)
# -- rotate_sd_3: double (nullable = true)
# -- vibration_ma_3: double (nullable = true)
# -- vibration_sd_3: double (nullable = true)
# -- volt_ma_3: double (nullable = true)
# -- volt_sd_3: double (nullable = true)
# -- error: integer (nullable = true)
#
# </div>

# %% [markdown]
# ## Pipeline
#
# Let's build some of the transformations we'll need in our pipeline, such as `VectorAssembler` and LogisticRegression`.

# %% [markdown]
# We create a feature vector with the input columns using [`VectorAssembler`](https://spark.apache.org/docs/latest/ml-features.html#vectorassembler), rescale them using [`StandardScaler`](https://spark.apache.org/docs/latest/ml-features.html#standardscaler) and create the output column `norm_features` which feed into [`LogisticRegression`](https://spark.apache.org/docs/latest/ml-classification-regression.html#logistic-regression) to create our classifier for predicting failure.

# %% [markdown]
# ### Hands-on lab
# Create a pipeline that contains three stages as specified above. Then fit the pipeline to the training data and use the fitted model to get predictions for the test data.

# %%
from pyspark.ml.feature import StandardScaler, VectorAssembler
from pyspark.ml.classification import LogisticRegression
from pyspark.ml import Pipeline

vassembler = VectorAssembler(inputCols = X_keep, outputCol = "features")
stndscaler = StandardScaler(inputCol = "features", outputCol = "norm_features")
# df_norm = stndscaler.transform(df_all)
# display(df_norm)

lr = (LogisticRegression()
     .setLabelCol("error")
     .setFeaturesCol("norm_features"))

pipeline = Pipeline(stages = [vassembler, stndscaler, lr])
print(pipeline.getStages())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[VectorAssembler_5448af3cdf34, StandardScaler_88f6b85d73be, LogisticRegression_aa99b406e041]
# </div>

# %%
lr_model = pipeline.fit(df_train)

df_pred = lr_model.transform(df_test).select("error", "rawPrediction", "prediction")
display(df_pred)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>error</th><th>rawPrediction</th><th>prediction</th></tr></thead><tbody><tr><td>0</td><td>List(1, 2, List(), List(4.487099562530801, -4.487099562530801))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(5.013388183023125, -5.013388183023125))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(5.6455802986316534, -5.6455802986316534))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(6.7664629395784495, -6.7664629395784495))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(6.827698084260586, -6.827698084260586))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(7.18702061962561, -7.18702061962561))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(6.8735934094136795, -6.8735934094136795))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(6.368971756277576, -6.368971756277576))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(6.257945908729084, -6.257945908729084))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(5.336610385963146, -5.336610385963146))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(5.876669435370518, -5.876669435370518))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(5.5441229426932, -5.5441229426932))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(5.8355870277965725, -5.8355870277965725))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(5.696845080410855, -5.696845080410855))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(5.206196488769065, -5.206196488769065))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(5.7282889288508585, -5.7282889288508585))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(5.9870864504663075, -5.9870864504663075))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(5.352078691947993, -5.352078691947993))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(4.969459028086735, -4.969459028086735))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(3.616263090108381, -3.616263090108381))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(3.076778380642285, -3.076778380642285))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(4.013831485105847, -4.013831485105847))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(4.719516960699455, -4.719516960699455))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(5.609538004015652, -5.609538004015652))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(5.206519276675694, -5.206519276675694))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(5.089495198710695, -5.089495198710695))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(5.155820278715192, -5.155820278715192))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(4.595385596846732, -4.595385596846732))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(4.814954432461118, -4.814954432461118))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(5.623932076473686, -5.623932076473686))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(4.682228759409188, -4.682228759409188))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(4.674115894667922, -4.674115894667922))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(4.8801188122116415, -4.8801188122116415))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(3.4587589637585197, -3.4587589637585197))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(4.013052160399491, -4.013052160399491))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(4.745944506363546, -4.745944506363546))</td><td>0.0</td></tr><tr><td>0</td><td>List(1, 2, List(), List(3.7051760827974807, -3.7051760827974807))</td><td> ...

# %% [markdown]
# ### End of lab

# %% [markdown]
# ## Evaluate the Model

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator

evaluator = BinaryClassificationEvaluator()
print(evaluator.explainParams())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">labelCol: label column name. (default: label)
# metricName: metric name in evaluation (areaUnderROC|areaUnderPR) (default: areaUnderROC)
# rawPredictionCol: raw prediction (a.k.a. confidence) column name. (default: rawPrediction)
# </div>

# %%
evaluator.setLabelCol("error")
evaluator.setRawPredictionCol('rawPrediction')

metricName = evaluator.getMetricName()
metricVal = evaluator.evaluate(df_pred)

print("{}: {}".format(metricName, metricVal))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">areaUnderROC: 0.8085509910372712
# </div>

# %% [markdown]
# We could wrap this into a function to make it easier to get the output of multiple metrics.

# %%
def printEval(df, labelCol = "error", rawPredictionCol = "rawPrediction"):
  evaluator = BinaryClassificationEvaluator()
  evaluator.setLabelCol(labelCol)
  evaluator.setRawPredictionCol(rawPredictionCol)

  auroc = evaluator.setMetricName("areaUnderROC").evaluate(df)
  aupr = evaluator.setMetricName("areaUnderPR").evaluate(df)
  print("AUROC: {}\nAUPR: {}".format(auroc, aupr))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
printEval(df_pred)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">AUROC: 0.8085509910372712
# AUPR: 0.11586068996057057
# </div>

# %% [markdown]
# ##Conclusion
# Hmmmm... our results are not great yet. We'll look into how to improve our results later.

# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
#
# Licensed under the MIT License.
